# %%
import os
import random
import re
import string

import nltk
import numpy as np
import pandas as pd

from gensim.models import Word2Vec

from nltk import word_tokenize
from nltk.corpus import stopwords

from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_samples, silhouette_score

nltk.download("stopwords")

SEED = 42
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/crystal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_pickle("sentiment_lg.pkl")

# %%
def clean_text(text, tokenizer, stopwords):

    text = str(text).lower()  # Lowercase words
    text = re.sub(r"\[(.*?)\]", "", text)  # Remove [+XYZ chars] in content
    text = re.sub(r"\s+", " ", text)  # Remove multiple spaces in content
    text = re.sub(r"\w+…|…", "", text)  # Remove ellipsis (and last word)
    text = re.sub(r"(?<=\w)-(?=\w)", " ", text)  # Replace dash between words
    text = re.sub(
        f"[{re.escape(string.punctuation)}]", "", text
    )  # Remove punctuation

    tokens = tokenizer(text)  # Get tokens from text
    tokens = [t for t in tokens if not t in stopwords]  # Remove stopwords
    tokens = ["" if t.isdigit() else t for t in tokens]  # Remove digits
    tokens = [t for t in tokens if len(t) > 1]  # Remove short tokens
    return tokens

# %%
text = df.copy()
text = text[["text_clean"]]

# %%
text
# Out:
#                                                text_clean
# 0       chicago  ap    chicago school leaders canceled...
# 1       chicago  ap    chicago school leaders canceled...
# 2       chicago pd       lies  season   episode    pro...
# 3       wise of foolish  the chicago tribune article t...
# 4       the neighbors near mashawn plummer s portage p...
# ...                                                   ...
# 181866  authorities say a girl who was shot in the hea...
# 181867  the no    seed loyola chicago ramblers        ...
# 181868  remember to check out the draftkings illinois ...
# 181869        buyer  address  valuation   jennifer a  ...
# 181870  chicago  ap    when russia invaded her home co...
#
# [181871 rows x 1 columns]

# %%
stopwords = stopwords.words("english")
text["tokens"] = text["text_clean"].map(lambda x: clean_text(x, word_tokenize, stopwords))

# %%
import gensim.downloader as api

# %%
#wv = api.load('word2vec-google-news-300')

# %%
wv.most_similar("resident")
# Out:
# [('resi_dent', 0.6230902671813965),
#  ('lifelong_resident', 0.602915346622467),
#  ('Resident', 0.6022466421127319),
#  ('residents', 0.5787309408187866),
#  ('retired_schoolteacher', 0.5495061278343201),
#  ('schoolteacher', 0.50212562084198),
#  ('citizen', 0.49899375438690186),
#  ('councilman', 0.4956853985786438),
#  ('Crumland_Farms', 0.4863513708114624),
#  ('Perne', 0.48625093698501587)]

# %%
wv.most_similar("population")
# Out:
# [('populations', 0.7653926610946655),
#  ('poulation', 0.6552072167396545),
#  ('popula_tion', 0.6456001996994019),
#  ('popu_lation', 0.5914971828460693),
#  ('populace', 0.5719559788703918),
#  ('pop_ulation', 0.570850670337677),
#  ('inhabitants', 0.5527059435844421),
#  ('populaton', 0.5474691987037659),
#  ('Population', 0.5354834198951721),
#  ('Demographers_predict', 0.5321643948554993)]

# %%
wv.most_similar("business")
# Out:
# [('businesses', 0.6623775362968445),
#  ('busines', 0.6080313920974731),
#  ('busi_ness', 0.5612965226173401),
#  ('PETER_PASSI_covers', 0.5530025959014893),
#  ('Business', 0.546613872051239),
#  ('businesss', 0.5441080331802368),
#  ('Sopris_supplemental_solutions', 0.525254487991333),
#  ('company', 0.5192003846168518),
#  ('entrepreneurial', 0.5077816247940063),
#  ('buiness', 0.5039401650428772)]

# %%
docs = text["text_clean"].values
tokenized_docs = text["tokens"].values

# %%
def vectorize(list_of_docs):
    
    features = []

    for tokens in list_of_docs:
        zero_vector = np.zeros(wv.vector_size)
        vectors = []
        for token in tokens:
            if token in wv:
                try:
                    vectors.append(wv[token])
                except KeyError:
                    continue
        if vectors:
            vectors = np.asarray(vectors)
            avg_vec = vectors.mean(axis=0)
            features.append(avg_vec)
        else:
            features.append(zero_vector)
    return features
    
vectorized_docs = vectorize(tokenized_docs)
#len(vectorized_docs), len(vectorized_docs[0])

# %%
def vectorize(list_of_docs):
    
    features = []

    for tokens in list_of_docs:
        vectors = []
        for token in tokens:
            if token in wv:
                try:
                    vectors.append(wv.similarity("resident",token))
                except KeyError:
                    continue
        if vectors:
            vectors = np.asarray(vectors)
            avg_vec = vectors.mean()
            features.append(avg_vec)
        else:
            features.append(0)
    return features
    
vectorized_docs = vectorize(tokenized_docs)

# %%
len(vectorized_docs)
# Out:
# 181871

# %%
model_google.similarity('chicago', 'university')

# %%
len(wv["population"])
# Out:
# 300

# %%
temp = df[["title","text","population","business","resident"]]
temp
# Out:
#                                                     title  \
# 0       No deal, no school: Chicago cancels classes fo...
# 1       No deal, no school: Chicago cancels classes fo...
# 2                  Watch ‘Chicago P.D.’ Preview Wednesday
# 3       Trump’s Solution for Chicago Public Schools? K...
# 4       Family, friends, colleagues gathering today at...
# ...                                                   ...
# 181866  Chicago girl shot after celebrating 12th birth...
# 181867  Loyola Chicago vs. Northern Iowa – MVC Tournam...
# 181868  DraftKings Illinois Promo Code: $1,050 Bonus a...
# 181869  Sidney, Illinois had a median home valuation o...
# 181870  Ukrainian woman weds Chicago fiancé ahead of r...
#
#                                                      text  population  \
# 0       CHICAGO (AP) — Chicago school leaders canceled...    0.094708
# 1       CHICAGO (AP) — Chicago school leaders canceled...    0.093367
# 2       Chicago PD 9×11 “Lies” Season 9 Episode 11 Pro...    0.067550
# 3       Wise of Foolish?\nThe Chicago Tribune article ...    0.104678
# 4       The neighbors near Mashawn Plummer’s Portage P...    0.061630
# ...                                                   ...         ...
# 181866  Authorities say a girl who was shot in the hea...    0.089800
# 181867  The No. 4 seed Loyola Chicago Ramblers (23-7, ...    0.078802
# 181868  Remember to check out the DraftKings Illinois ...    0.038728
# 181869  [BlockShopper.com] .\n|Buyer||Address||Valuati...    0.064628
# 181870  CHICAGO (AP) — When Russia invaded her home co...    0.069167
#
#         business  resident
# 0       0.089997  0.068338
# 1       0.090444  0.068236
# 2       0.102209  0.044861
# 3       0.095248  0.058324
# 4       0.076524  0.123947
# ...          ...       ...
# 181866  0.061380  0.136115
# 181867  0.049178  0.026299
# 181868  0.078272  0.004489
# 181869  0.125551  0.071950
# 181870  0.064465  0.072688
#
# [181871 rows x 5 columns]

# %%
df["resident"] = vectorized_docs
df
# Out:
#              date language                                              title  \
# 0      2022-01-06  english  No deal, no school: Chicago cancels classes fo...
# 1      2022-01-06  english  No deal, no school: Chicago cancels classes fo...
# 2      2022-01-06  english             Watch ‘Chicago P.D.’ Preview Wednesday
# 3      2022-01-06  english  Trump’s Solution for Chicago Public Schools? K...
# 4      2022-01-06  english  Family, friends, colleagues gathering today at...
# ...           ...      ...                                                ...
# 181866 2022-03-05  english  Chicago girl shot after celebrating 12th birth...
# 181867 2022-03-05  english  Loyola Chicago vs. Northern Iowa – MVC Tournam...
# 181868 2022-03-05  english  DraftKings Illinois Promo Code: $1,050 Bonus a...
# 181869 2022-03-05  english  Sidney, Illinois had a median home valuation o...
# 181870 2022-03-06  english  Ukrainian woman weds Chicago fiancé ahead of r...
#
#                                                      text  \
# 0       CHICAGO (AP) — Chicago school leaders canceled...
# 1       CHICAGO (AP) — Chicago school leaders canceled...
# 2       Chicago PD 9×11 “Lies” Season 9 Episode 11 Pro...
# 3       Wise of Foolish?\nThe Chicago Tribune article ...
# 4       The neighbors near Mashawn Plummer’s Portage P...
# ...                                                   ...
# 181866  Authorities say a girl who was shot in the hea...
# 181867  The No. 4 seed Loyola Chicago Ramblers (23-7, ...
# 181868  Remember to check out the DraftKings Illinois ...
# 181869  [BlockShopper.com] .\n|Buyer||Address||Valuati...
# 181870  CHICAGO (AP) — When Russia invaded her home co...
#
#                                                text_clean  cluster  topic1  \
# 0       chicago  ap    chicago school leaders canceled...        0       1
# 1       chicago  ap    chicago school leaders canceled...        0       1
# 2       chicago pd       lies  season   episode    pro...        0       6
# 3       wise of foolish  the chicago tribune article t...        0      12
# 4       the neighbors near mashawn plummer s portage p...        0       6
# ...                                                   ...      ...     ...
# 181866  authorities say a girl who was shot in the hea...        0       2
# 181867  the no    seed loyola chicago ramblers        ...        0      15
# 181868  remember to check out the draftkings illinois ...        0      10
# 181869        buyer  address  valuation   jennifer a  ...        0      11
# 181870  chicago  ap    when russia invaded her home co...        0       7
#
#               w1  topic2        w2  topic3        w3  Topic_cluster  \
# 0       0.998010     NaN       NaN     NaN       NaN              7
# 1       0.998145     NaN       NaN     NaN       NaN             10
# 2       0.689289     0.0  0.214598    17.0  0.061193              4
# 3       0.457139     1.0  0.322744     6.0  0.075293              4
# 4       0.569758     2.0  0.336124     3.0  0.080211              1
# ...          ...     ...       ...     ...       ...            ...
# 181866  0.898170     0.0  0.013380     1.0  0.010981              4
# 181867  0.662747     3.0  0.177199    14.0  0.083335              2
# 181868  0.451471    16.0  0.335602    13.0  0.176749              4
# 181869  0.924808    18.0  0.033204    12.0  0.028433              8
# 181870  0.452191     6.0  0.360106    15.0  0.103554              4
#
#         sentiment  sentiment_prob_0  sentiment_prob_1  population  business  \
# 0               0          1.000000      5.045681e-16    0.094708  0.089997
# 1               0          1.000000      4.040775e-19    0.093367  0.090444
# 2               1          0.246794      7.532063e-01    0.067550  0.102209
# 3               0          1.000000      5.159463e-09    0.104678  0.095248
# 4               1          0.004937      9.950635e-01    0.061630  0.076524
# ...           ...               ...               ...         ...       ...
# 181866          0          0.814880      1.851205e-01    0.089800  0.061380
# 181867          1          0.000028      9.999719e-01    0.078802  0.049178
# 181868          0          0.414387      5.856135e-01    0.038728  0.078272
# 181869          1          0.559324      4.406761e-01    0.064628  0.125551
# 181870          0          1.000000      2.481131e-28    0.069167  0.064465
#
#         resident
# 0       0.068338
# 1       0.068236
# 2       0.044861
# 3       0.058324
# 4       0.123947
# ...          ...
# 181866  0.136115
# 181867  0.026299
# 181868  0.004489
# 181869  0.071950
# 181870  0.072688
#
# [181871 rows x 19 columns]

# %%
len(vectorized_docs),len(vectorized_docs[0])
# Out:
# (181871, 300)

# %%
#df["population"] = mean_relative

# %%
df.to_pickle("data_with_similarity.pkl")
